# %%
# !pip install cropnet
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.0/55.0 kB 4.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
# !apt install libeccodes-dev
# !pip install eccodes
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libeccodes-data libeccodes0
# The following NEW packages will be installed:
#   libeccodes-data libeccodes-dev libeccodes0
# 0 upgraded, 3 newly installed, 0 to remove and 45 not upgraded.
# Need to get 3,076 kB of archives.
# After this operation, 60.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libeccodes-data all 2.24.2-1 [1,592 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libeccodes0 amd64 2.24.2-1 [614 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libeccodes-dev amd64 2.24.2-1 [870 kB]
# Fetched 3,076 kB in 0s (14.6 MB/s)
# Selecting previously unselected package libeccodes-data.
# (Reading database ... 123588 files and directories currently installed.)
# Preparing to unpack .../libeccodes-data_2.24.2-1_all.deb ...
# ...

# %%
from cropnet.data_downloader import DataDownloader

# Use the "target_dir" to specify where the data should be downloaded to
downloader = DataDownloader(target_dir="./data")
# Out:
#  ╭─▌▌Herbie─────────────────────────────────────────────╮
#  │ INFO: Created a default config file.                 │
#  │ You may view/edit Herbie's configuration here:       │
#  │          /root/.config/herbie/config.toml            │
#  ╰──────────────────────────────────────────────────────╯

# %%
# Download 2022 USDA Soybean data

# %%
# Download the 2023 (the 1st and 2nd quarters) Sentinel-2 Imagery
downloader.download_Sentinel2(fips_codes=["10003", "22007"], years=["2022"], image_type="AG")
downloader.download_Sentinel2(fips_codes=["10003", "22007"], years=["2022"], image_type="NDVI")
# Out:
# ...
# Year Progress: [1 / 1], Downloading 2022's AG Imagery for the county 10003
# ...
# dates processed: 100%|██████████| 6/6 [00:00<00:00,  8.71it/s]
# ...
# Year Progress: [1 / 1], Downloading 2022's AG Imagery for the county 22007
# ...
# dates processed: 100%|██████████| 6/6 [00:00<00:00,  7.27it/s]
# ...
# Year Progress: [1 / 1], Downloading 2022's NDVI Imagery for the county 10003
# ...
# dates processed: 100%|██████████| 6/6 [00:00<00:00,  8.69it/s]
# ...
# Year Progress: [1 / 1], Downloading 2022's NDVI Imagery for the county 22007
# ...
# dates processed: 100%|██████████| 6/6 [00:00<00:00,  8.60it/s]

# %%
sent_de_2022 =  downloader.download_Sentinel2(fips_codes=["10003"], years=["2022"], image_type="AG")
# Out:
# ...
# Year Progress: [1 / 1], Downloading 2022's AG Imagery for the county 10003
# ...
# dates processed: 100%|██████████| 6/6 [00:00<00:00,  8.11it/s]

# %%
sent_de_2022.dtype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-75b1316a4047> in <cell line: 1>()
# ----> 1 sent_de_2022.dtype()
#
# AttributeError: 'NoneType' object has no attribute 'dtype'

# %%
downloader.download_USDA("Soybean", fips_codes=["10003", "22007"], years=["2022"])
# Out:
# Progress: [ 1/1 ], Downloading USDA Data, Year: 2022, Crop: Soybean

# %%
# Download the 2023 (January to July) WRF-HRRR data
downloader.download_HRRR(fips_codes=["10003", "22007"], years=["2022"])
# Out:
# Start to download 2022 WRF-HRRR data for counties: ['10003', '22007']
# ...
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2022-Jan-01 00:00 UTC F00 ┊ GRIB2 @ pando ┊ IDX @ pando
# 👨🏻‍🏭 Created directory: [data/HRRR/hrrr/20220101]
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2022-Jan-01 00:00 UTC F01 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2022-Jan-01 01:00 UTC F00 ┊ GRIB2 @ pando ┊ IDX @ pando
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2022-Jan-01 01:00 UTC F01 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2022-Jan-01 02:00 UTC F00 ┊ GRIB2 @ pando ┊ IDX @ pando
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2022-Jan-01 02:00 UTC F01 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2022-Jan-01 03:00 UTC F00 ┊ GRIB2 @ pando ┊ IDX @ pando
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2022-Jan-01 03:00 UTC F01 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2022-Jan-01 04:00 UTC F00 ┊ GRIB2 @ pando ┊ IDX @ pando
# ...

# %%
downloader.download_USDA("Soybean", fips_codes=["10003", "22007"], years=["2022"])

# Download the 2023 (the 1st and 2nd quarters) Sentinel-2 Imagery
downloader.download_Sentinel2(fips_codes=["10003", "22007"], years=["2023"], image_type="AG")
downloader.download_Sentinel2(fips_codes=["10003", "22007"], years=["2023"], image_type="NDVI")

# Download the 2023 (January to July) WRF-HRRR data
downloader.download_HRRR(fips_codes=["10003", "22007"], years=["2023"])
# Out:
# Progress: [ 1/1 ], Downloading USDA Data, Year: 2022, Crop: Soybean
# ...
# Year Progress: [1 / 1], Downloading 2023's AG Imagery for the county 10003
# ...
# dates processed: 100%|██████████| 6/6 [00:00<00:00,  7.95it/s]
# ...
# Year Progress: [1 / 1], Downloading 2023's AG Imagery for the county 22007
# ...
# dates processed: 100%|██████████| 6/6 [00:00<00:00,  8.09it/s]
# ...
# Year Progress: [1 / 1], Downloading 2023's NDVI Imagery for the county 10003
# ...
# dates processed: 100%|██████████| 6/6 [00:00<00:00,  7.85it/s]
# ...
# Year Progress: [1 / 1], Downloading 2023's NDVI Imagery for the county 22007
# ...
# dates processed: 100%|██████████| 6/6 [00:00<00:00,  7.86it/s]
# Start to download 2023 WRF-HRRR data for counties: ['10003', '22007']
# ...
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2023-Jan-01 00:00 UTC F00 ┊ GRIB2 @ pando ┊ IDX @ pando
# 👨🏻‍🏭 Created directory: [data/HRRR/hrrr/20230101]
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2023-Jan-01 00:00 UTC F01 ┊ GRIB2 @ aws ┊ IDX @ aws
# ...

# %%
downloader.download_USDA("Soybean", fips_codes=["10003", "22007"], years=["2022"])
# Out:
# Progress: [ 1/1 ], Downloading USDA Data, Year: 2022, Crop: Soybean

# %%
import os
import pandas as pd
import numpy as np
import plotly.figure_factory as ff


# file path for accessing a particular file
file_path = "/content/data/USDA/data/Soybean/2022/USDA_Soybean_County_2022.csv"

path = os.path.join(file_path)
df = pd.read_csv(path)

df.head()
# Out:
#   commodity_desc reference_period_desc  year  state_ansi state_name  \
# 0       SOYBEANS                  YEAR  2022          10   DELAWARE
# 1       SOYBEANS                  YEAR  2022          22  LOUISIANA
#
#    county_ansi county_name  asd_code       asd_desc domain_desc source_desc  \
# 0            3  NEW CASTLE        20       NORTHERN       TOTAL      SURVEY
# 1            7  ASSUMPTION        80  SOUTH CENTRAL       TOTAL      SURVEY
#
#   agg_level_desc  PRODUCTION, MEASURED IN BU  YIELD, MEASURED IN BU / ACRE
# 0         COUNTY                    782000.0                          36.9
# 1         COUNTY                    140000.0                          50.0

# %%
downloader.download_Sentinel2(fips_codes=["10003", "22007"], years=["2022"], image_type="AG")
downloader.download_Sentinel2(fips_codes=["10003", "22007"], years=["2022"], image_type="NDVI")
# Out:
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2023-Jan-18 12:00 UTC F00 ┊ GRIB2 @ pando ┊ IDX @ pando
# ...
# Year Progress: [1 / 1], Downloading 2022's AG Imagery for the county 10003
# ...
# dates processed: 100%|██████████| 6/6 [00:01<00:00,  5.66it/s]
# ...
# Year Progress: [1 / 1], Downloading 2022's AG Imagery for the county 22007
# ...
# dates processed:   0%|          | 0/6 [00:00<?, ?it/s]
# Could not find PRECIP grib for date 20230118
# ...
# dates processed:   0%|          | 0/6 [00:00<?, ?it/s]
# 🤝🏻⛔ Bad handshake with pando? Am I able to move on?
# dates processed: 100%|██████████| 6/6 [00:01<00:00,  3.44it/s]
# 🤝🏻⛔ Bad handshake with pando? Am I able to move on?
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2023-Jan-18 13:00 UTC F00 ┊ GRIB2 @ pando ┊ IDX @ pando
# ...
# Year Progress: [1 / 1], Downloading 2022's NDVI Imagery for the county 10003
# ...
# dates processed: 100%|██████████| 6/6 [00:00<00:00,  6.73it/s]
# ...
# Year Progress: [1 / 1], Downloading 2022's NDVI Imagery for the county 22007
# ...

# %%
downloader.download_HRRR(fips_codes=["10003", "22007"], years=["2022"])
# Out:
# Start to download 2022 WRF-HRRR data for counties: ['10003', '22007']
# ...
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2022-Jan-01 00:00 UTC F00 ┊ GRIB2 @ pando ┊ IDX @ pando
# Could not download herbo for 20220101
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2022-Jan-01 00:00 UTC F01 ┊ GRIB2 @ aws ┊ IDX @ aws
# Successfully download 2022 WRF-HRRR data for counties: ['10003', '22007']

# %%
import tensorflow as tf
import os
import json
import pandas as pd

class USDACropDataset(tf.data.Dataset):

    def __init__(self, base_dir, config_file, crop_type="Soybeans"):
        """
        Dataset for the USDA Crop Dataset

        :param base_dir: the root directory for CropNet dataset, e.g., /mnt/data/CropNet
        :param config_file: the path for JSON configuration file
        :param crop_type: the crop type for use. Choices: ["Corn", "Cotton", "Soybeans", "Winter Wheat"]
        """

        all_crop_types = ["Corn", "Cotton", "Soybeans", "Winter Wheat"]

        # validate the crop type
        assert crop_type in all_crop_types, f"Cannot find a crop type named {crop_type} in the USDA Crop Dataset."

        self.crop_type = crop_type

        if crop_type == "Cotton":
            self.column_names = ['PRODUCTION, MEASURED IN 480 LB BALES', 'YIELD, MEASURED IN BU / ACRE']
        else:
            self.column_names = ['PRODUCTION, MEASURED IN BU', 'YIELD, MEASURED IN BU / ACRE']

        self.file_paths = []
        self.fips_codes = []
        self.years = []
        self.state_ansi = []
        self.county_ansi = []

        with open(config_file, 'r') as f:
            data = json.load(f)

        for obj in data:
            self.fips_codes.append(obj["FIPS"])
            self.years.append(obj["year"])
            self.state_ansi.append(obj["state_ansi"])
            self.county_ansi.append(obj["county_ansi"])

            relative_path = obj["data"]["USDA"]
            self.file_paths.append(os.path.join(base_dir, relative_path))

    def _parse_csv(self, file_path, state_ansi, county_ansi):
        # Read the CSV file into a TensorFlow dataset
        dataset = tf.data.experimental.CsvDataset(
            file_path,
            [tf.float32] * len(self.column_names),
            header=True,
            field_delim=','
        )

        # Convert the dataset to a DataFrame
        data = []
        for row in dataset:
            data.append(row)

        df = pd.DataFrame(data, columns=self.column_names)

        # convert state_ansi and county_ansi to string with leading zeros
        df['state_ansi'] = df['state_ansi'].astype(str).str.zfill(2)
        df['county_ansi'] = df['county_ansi'].astype(str).str.zfill(3)

        # Filter the DataFrame
        df = df[(df["state_ansi"] == state_ansi) & (df["county_ansi"] == county_ansi)]

        # Convert to tensor
        x = tf.convert_to_tensor(df[self.column_names].values, dtype=tf.float32)
        x = tf.math.log(tf.reshape(x, [-1]))  # Flatten and apply log transformation

        return x

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, index):
        fips_code, year = self.fips_codes[index], self.years[index]
        state_ansi, county_ansi = self.state_ansi[index], self.county_ansi[index]

        file_path = self.file_paths[index]
        x = self._parse_csv(file_path, state_ansi, county_ansi)

        return x, fips_code, year

    def get_dataset(self):
        def generator():
            for i in range(len(self.file_paths)):
                yield self[i]

        dataset = tf.data.Dataset.from_generator(
            generator,
            output_signature=(
                tf.TensorSpec(shape=(None,), dtype=tf.float32),
                tf.TensorSpec(shape=(), dtype=tf.string),
                tf.TensorSpec(shape=(), dtype=tf.int32)
            )
        )

        return dataset
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-2c602f25037c> in <cell line: 1>()
# ----> 1 import tensorflow as tf
#       2 import os
#       3 import json
#       4 import pandas as pd
#       5
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/__init__.py in <module>
#      52 from tensorflow._api.v2 import autograph
#      53 from tensorflow._api.v2 import bitwise
# ---> 54 from tensorflow._api.v2 import compat
#      55 from tensorflow._api.v2 import config
#      56 from tensorflow._api.v2 import data
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/_api/v2/compat/__init__.py in <module>
#       6 import sys as _sys
#       7
# ----> 8 from tensorflow._api.v2.compat import v1
#       9 from tensorflow._api.v2.compat import v2
#      10 from tensorflow.python.compat.compat import forward_compatibility_horizon # line: 125
#
# ...
